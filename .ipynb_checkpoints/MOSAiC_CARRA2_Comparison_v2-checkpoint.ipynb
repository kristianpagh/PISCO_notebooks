# %%
import os
import subprocess
import json
from pathlib import Path
import numpy as np
import pandas as pd
import earthkit.data
import matplotlib.pyplot as plt
import logging, warnings
import xarray as xr
import sys
from netCDF4 import Dataset
import netCDF4 as nc
import cartopy.crs as ccrs
from eccodes import (
    codes_grib_new_from_file,
    codes_get,
    codes_get_array,
    codes_get_values,
    codes_release,
)
import gc

# %%
# Code adapted from Ulrike
def mosaic_track_select(time_start,time_end,file_dir):
    PERIOD = slice(time_start,time_end)

    obs = xr.open_dataset(file_dir).sel(time=PERIOD)
    obs_t2m = obs.temp_2m.to_series()  # deg C
    obs_wspd_10m = obs.wspd_vec_mean_10m.to_series()  # deg C
    mosaic_track = pd.DataFrame({
        "lat": obs.lat.to_series(),
        "lon": obs.lon.to_series()})
    
    # Temp
    print(f"{obs_t2m.notna().sum()} of {len(obs_t2m)} hourly obs available, "
          f"{obs_t2m.index[0]} .. {obs_t2m.index[-1]}")
    print(obs_t2m.describe().round(2))
    # Wind speed
    print(f"{obs_wspd_10m.notna().sum()} of {len(obs_wspd_10m)} hourly obs available, "
          f"{obs_wspd_10m.index[0]} .. {obs_wspd_10m.index[-1]}")
    print(obs_wspd_10m.describe().round(2))

    return(mosaic_track,obs_t2m,obs_wspd_10m)

def mosaic_latlon_select(mosaic_track,buffer_km):
    print(f"mosaic min lon {mosaic_track['lon'].min()}")
    print(f"mosaic max lon {mosaic_track['lon'].max()}")
    
    print(f"mosaic min lat {mosaic_track['lat'].min()}")
    print(f"mosaic max lat {mosaic_track['lat'].max()}")
    
    track_min_lat = mosaic_track["lat"].min()
    track_max_lat = mosaic_track["lat"].max()
    track_min_lon = mosaic_track["lon"].min()
    track_max_lon = mosaic_track["lon"].max()
    
    # Approximate latitude distance: 1 degree latitude ≈ 111.3 km
    lat_buffer = buffer_km / 111.32
    
    # Longitude distance depends on latitude.
    # Use the lowest latitude to give a conservative buffer.
    mean_lat = track_min_lat
    lon_buffer = buffer_km / (111.32 * np.cos(np.deg2rad(mean_lat)))
    
    min_lat = track_min_lat - lat_buffer
    max_lat = track_max_lat + lat_buffer
    
    min_lon = track_min_lon - lon_buffer
    max_lon = track_max_lon + lon_buffer
    
    print("Crop bounds:")
    print(f"lat: {min_lat:.3f} to {max_lat:.3f}")
    print(f"lon: {min_lon:.3f} to {max_lon:.3f}")

    return(min_lat,max_lat,min_lon,max_lon)

# %%
# Stats Functions 

def absdiff(df_input1,df_input2):
    """
    Calculate absolute difference between two datasets
    
    Parameters
    ----------
    df_input1,df_input2: pd dataframe columns
        dataframe columns must have the same length
    
    Returns
    -------
    Value:
        The mean absolute difference between the two dataframe columns

    """
    mask = (~np.isnan(df_input1)) & (~np.isnan(df_input2))

    abs_diff = np.abs(df_input1[mask] - df_input2[mask])
    
    mean_abs_diff = np.nanmean(abs_diff)
    return(mean_abs_diff)

def corr_squared(df_input1,df_input2):
    """
    Calculate r squared of two datasets
    
    Parameters
    ----------
    df_input1,df_input2: pd dataframe columns
        dataframe columns must have the same length
    
    Returns
    -------
    Value:
        The r squared value of the two dataframe columns

    """
    mask = (~np.isnan(df_input1)) & (~np.isnan(df_input2))

    x = df_input1[mask]
    y = df_input2[mask]

    r = np.corrcoef(x, y)[0, 1]

    r2 = r**2
    return(r2)

def corr(df_input1,df_input2):
    """
    Calculate r of two datasets
    
    Parameters
    ----------
    df_input1,df_input2: pd dataframe columns
        dataframe columns must have the same length
    
    Returns
    -------
    Value:
        The r value of the two dataframe columns

    """
    mask = (~np.isnan(df_input1)) & (~np.isnan(df_input2))

    x = df_input1[mask]
    y = df_input2[mask]

    r = np.corrcoef(x, y)[0, 1]
    return(r)

def rmsd(df_input1,df_input2):
    """
    Calculate rmsd of two datasets
    
    Parameters
    ----------
    df_input1,df_input2: pd dataframe columns
        dataframe columns must have the same length
    
    Returns
    -------
    Value:
        The rmsd value of the two dataframe columns

    """
    mask = (~np.isnan(df_input1)) & (~np.isnan(df_input2))

    diff_squared = (df_input1[mask] - df_input2[mask])**2

    rmsd = np.sqrt(np.mean(diff_squared))
    return(rmsd)

# %% [markdown]
# # Slice CARRA2 Data

# %% [markdown]
# ## Process MOSAiC track for time period

# %% [markdown]
# This can be upgraded to a loop but I used manual monthly inputs to investigate the results

# %%
time_start = '2019-12-01'
time_end = '2019-12-31'

# Slice the MOSAIC track for the given timeframe and create a lat/lon buffer (default is 50)
mosaic_track, obs_t2m, obs_wspd_10m = mosaic_track_select(time_start,time_end,f"{base_dir}/mosaic-examples/MOSAiC_obs_combined_1h_v2.nc")
min_lat,max_lat,min_lon,max_lon = mosaic_latlon_select(mosaic_track,50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/mambaforge/base/envs/poly-ex/lib/python3.14/site-packages/xarray/backends/file_manager.py:219, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     218 try:
# --> 219     file = self._cache[self._key]
#     220 except KeyError:
#
# File /opt/homebrew/Caskroom/mambaforge/base/envs/poly-ex/lib/python3.14/site-packages/xarray/backends/lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# ...

# %% [markdown]
# ## Apply to Carra2 Data

# %%
grib_file = f"{base_dir}CARRA2/CARRA_201912_Analysis_Wspd_2mTemp_SIF.grib"
output_dir = f"{base_dir}CARRA2/MOSAiC_Subsets/Monthly/"

month_save = '201912'

# t2m + wspd10 combined - same native grid, confirmed above
params = {
    "file_dir": grib_file,
    "shortname_variable_map": {"2t": "t2m", "10si": "wspd10"},
    "time_start": time_start,
    "time_end": time_end,   # inclusive - a full week in one call
    "min_lat": min_lat, "max_lat": max_lat,
    "min_lon": min_lon, "max_lon": max_lon,
    "out_path": f"{output_dir}CARRA2_{month_save}_MOSAiC_t2m_wspd10.nc", # This will fail if the file already exists
}

result = subprocess.run(
    [sys.executable, "extract_carra2_mosaic.py", json.dumps(params)],
    capture_output=True, text=True,
)
print(result.stdout)
if result.returncode != 0:
    print("FAILED:\n", result.stderr)
# Out:
# [log] start: RSS=105.6 MB
#   2t: scanned 268, kept 268 in window
#   10si: scanned 268, kept 268 in window
# [log] after extraction: RSS=323.0 MB
# [log] after to_netcdf: RSS=329.6 MB
# Saved C:/Users/Administrator/Documents/SnowPI_Hackathon/CARRA2/MOSAiC_Subsets/Monthly/CARRA2_201912_MOSAiC_t2m_wspd10.nc

# %% [markdown]
# # Nearest CARRA2 MOSAiC Point

# %%
# Code from Ulrike
def nearest_index(lat0, lon0, lat2d, lon2d):
    """Index of the grid point closest to (lat0, lon0), great-circle distance."""
    la, lo = np.radians(lat2d), np.radians(lon2d)
    d = np.arccos(np.clip(
        np.sin(np.radians(lat0)) * np.sin(la)
        + np.cos(np.radians(lat0)) * np.cos(la) * np.cos(lo - np.radians(lon0)),
        -1, 1))
    return np.unravel_index(np.nanargmin(d), d.shape)

def nearest_mosaic_carra2(carra2,input_variable,mosaic_track,mosaic_obs):
    c_var = carra2[input_variable].load()              
    c_lat = carra2.latitude.values
    c_lon = (carra2.longitude.values + 180) % 360 - 180
    c_times = pd.DatetimeIndex(carra2.time.values)

    if not c_times.is_unique:
        print(
            f"WARNING: {input_variable} contains "
            f"{c_times.duplicated().sum()} duplicate timestamps."
        )
    
        keep = ~c_times.duplicated()
    
        c_var = c_var.isel(time=keep)
        c_times = c_times[keep]
    
        print(f"Removed {np.sum(~keep)} duplicate timestamps.")
    
    timen = "time"
    print(f"cropped grid: {c_lat.shape}, {c_times[0]} .. {c_times[-1]} ({len(c_times)} analyses)")

    pos = mosaic_track.reindex(c_times, method="nearest", tolerance=pd.Timedelta("1h"))

    vals, dists = [], []
    spatial_dims = [d for d in c_var.dims if d != timen]
    for i, t in enumerate(c_times):
        if np.isnan(pos["lat"].iloc[i]):
            vals.append(np.nan); dists.append(np.nan); continue
        iy, ix = nearest_index(pos["lat"].iloc[i], pos["lon"].iloc[i], c_lat, c_lon)
        vals.append(float(c_var.isel({timen: i, spatial_dims[0]: iy, spatial_dims[1]: ix})))
        dists.append(6371.0 * np.arccos(np.clip(
            np.sin(np.radians(pos['lat'].iloc[i])) * np.sin(np.radians(c_lat[iy, ix]))
            + np.cos(np.radians(pos['lat'].iloc[i])) * np.cos(np.radians(c_lat[iy, ix]))
            * np.cos(np.radians(c_lon[iy, ix] - pos['lon'].iloc[i])), -1, 1)))
    
    carra_var = pd.Series(vals, index=c_times, name="CARRA2")
    if carra_var.mean() > 150:          # K -> deg C if needed
        carra_var -= K0
    print(f"{carra_var.notna().sum()} CARRA2 values at the floe, "
          f"max distance to nearest grid point: {np.nanmax(dists):.2f} km")
    carra_var.describe().round(2)

    df = pd.DataFrame({"MOSAiC obs": mosaic_obs,
        "CARRA2": carra_var})
    common = df.dropna() 

    return(common)

def hourly_timestamp(input_df,timestamp):
    input_df['Datetime'] = pd.to_datetime(input_df['Date'])
    input_df_all = input_df.set_index('Datetime')
    full_time = pd.date_range(
        input_df_all.index.min(),
        input_df_all.index.max(),
        freq=timestamp)
    input_all_full = input_df_all.reindex(full_time)
    input_all_full.index.name = 'Datetime'
    input_all_full = input_all_full.reset_index()   

    return(input_all_full)

# %% [markdown]
# ## One File

# %%
K0 = 273.15
time_start = '2020-01-01'
time_end = '2020-01-31'
mosaic_track, obs_t2m, obs_wspd_10m = mosaic_track_select(time_start,time_end,f"{base_dir}/mosaic-examples/MOSAiC_obs_combined_1h_v2.nc")

carra2 = xr.open_dataset(f"C:/Users/Administrator/Documents/SnowPI_Hackathon/CARRA2/MOSAiC_Subsets/Monthly/CARRA2_202001_MOSAiC_t2m_wspd10.nc")
t2m_df = nearest_mosaic_carra2(carra2,'t2m',mosaic_track,obs_t2m)
wspd_df = nearest_mosaic_carra2(carra2,'wspd10',mosaic_track,obs_wspd_10m)
# Out:
# 703 of 744 hourly obs available, 2020-01-01 00:00:00 .. 2020-01-31 23:00:00
# count    703.00
# mean     -27.81
# std        3.89
# min      -36.69
# 25%      -30.53
# 50%      -28.23
# 75%      -25.46
# max      -11.36
# Name: temp_2m, dtype: float64
# 744 of 744 hourly obs available, 2020-01-01 00:00:00 .. 2020-01-31 23:00:00
# count    744.00
# mean       5.51
# std        2.26
# min        0.68
# 25%        3.59
# 50%        5.38
# 75%        7.26
# max       11.46
# Name: wspd_vec_mean_10m, dtype: float64
# cropped grid: (117, 117), 2020-01-01 00:00:00 .. 2020-01-31 21:00:00 (248 analyses)
# 248 CARRA2 values at the floe, max distance to nearest grid point: 1.65 km
# cropped grid: (117, 117), 2020-01-01 00:00:00 .. 2020-01-31 21:00:00 (248 analyses)
# 248 CARRA2 values at the floe, max distance to nearest grid point: 1.65 km

# %%
fig, ax = plt.subplots(2,1,figsize=(12, 8))
ax[0].plot(wspd_df['MOSAiC obs'], lw=1, color='steelblue',label='MOSAiC')
ax[0].plot(wspd_df['CARRA2'], lw=1, color='darkorange',label='CARRA2')
ax[0].set_ylabel('10m wind speed (m s$^{-1}$)',fontsize=12)

ax[1].plot(t2m_df['MOSAiC obs'], lw=1, color='steelblue')
ax[1].plot(t2m_df['CARRA2'], lw=1, color='darkorange')
ax[1].set_ylabel('2m temperature ($^{o}$C)',fontsize=12)

for i in range(0,2):
    ax[i].grid(linewidth = 0.6)

ax[1].set_xlabel('Date')
ax[0].legend(fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## All Months

# %%
months = ['201910','201911','201912','202001','202002',
          '202003','202004','202005','202006','202007','202008']

t2m_dfs, wspd_dfs = [],[]

K0 = 273.15
for month in months[:]:
    carra2 = xr.open_dataset(f"{base_dir}CARRA2/MOSAiC_Subsets/Monthly/CARRA2_{month}_MOSAiC_t2m_wspd10.nc")

    time_start = pd.to_datetime(month, format='%Y%m').strftime('%Y-%m-%d')
    time_end = (pd.to_datetime(month, format='%Y%m') + pd.offsets.MonthEnd(1)).strftime('%Y-%m-%d')
    mosaic_track, obs_t2m, obs_wspd_10m = mosaic_track_select(time_start,time_end,f"{base_dir}/mosaic-examples/MOSAiC_obs_combined_1h_v2.nc")

    t2m_df = nearest_mosaic_carra2(carra2,'t2m',mosaic_track,obs_t2m)
    wspd_df = nearest_mosaic_carra2(carra2,'wspd10',mosaic_track,obs_wspd_10m)

    t2m_df = t2m_df.reset_index()
    wspd_df = wspd_df.reset_index()

    t2m_dfs.append(t2m_df)
    wspd_dfs.append(wspd_df)

t2m_all = pd.concat(t2m_dfs, ignore_index=True)
wspd_all = pd.concat(wspd_dfs, ignore_index=True)
# Out:
# 187 of 744 hourly obs available, 2019-10-01 00:00:00 .. 2019-10-31 23:00:00
# count    187.00
# mean     -19.68
# std        4.15
# min      -26.18
# 25%      -22.87
# 50%      -20.67
# 75%      -16.01
# max      -11.40
# Name: temp_2m, dtype: float64
# 187 of 744 hourly obs available, 2019-10-01 00:00:00 .. 2019-10-31 23:00:00
# count    187.00
# mean       5.59
# std        1.27
# min        2.93
# 25%        4.46
# 50%        5.54
# 75%        6.52
# max        8.55
# Name: wspd_vec_mean_10m, dtype: float64
# cropped grid: (109, 110), 2019-10-01 00:00:00 .. 2019-10-31 21:00:00 (248 analyses)
# 248 CARRA2 values at the floe, max distance to nearest grid point: 1.73 km
# cropped grid: (109, 110), 2019-10-01 00:00:00 .. 2019-10-31 21:00:00 (248 analyses)
# 248 CARRA2 values at the floe, max distance to nearest grid point: 1.73 km
# 644 of 720 hourly obs available, 2019-11-01 00:00:00 .. 2019-11-30 23:00:00
# count    644.00
# mean     -20.32
# std        6.05
# min      -31.89
# ...

# %%
# Insert 3hourly timestamps
wspd_all.rename(columns={'index': 'Date'}, inplace=True) 
t2m_all.rename(columns={'index': 'Date'}, inplace=True) 

wspd_all_full = hourly_timestamp(wspd_all,'3h')
t2m_all_full = hourly_timestamp(t2m_all,'3h')

wspd_all_full.to_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/WindSpeed10m_CARRA2_MOSAiC.csv",index = False)
t2m_all_full.to_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/Temp2m_CARRA2_MOSAiC.csv",index = False)

# %% [markdown]
# ## Plotting

# %%
wspd_all_full = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/WindSpeed10m_CARRA2_MOSAiC.csv")
wspd_all_full['Datetime'] = pd.to_datetime(wspd_all_full['Date'])
t2m_all_full = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/Temp2m_CARRA2_MOSAiC.csv")
t2m_all_full['Datetime'] = pd.to_datetime(t2m_all_full['Date'])

# %% [markdown]
# ### Carmen Code Destination Earth

# %%
K0 = 273.15
t2m_ifs_hist = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/Temp2m_IFS_Hist_MOSAiC.csv",index_col=0)
t2m_ifs_ctrl = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/Temp2m_IFS_Ctrl_MOSAiC.csv",index_col=0)
t2m_ifs_hist['2t'] = t2m_ifs_hist['2t'] - K0
t2m_ifs_ctrl['2t'] = t2m_ifs_ctrl['2t'] - K0

wspd_ifs_hist = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/WindSpeed10m_IFS_Hist_MOSAiC.csv",index_col=0)
wspd_ifs_ctrl = pd.read_csv(f"{base_dir}CARRA2/MOSAiC_Subsets/WindSpeed10m_IFS_Ctrl_MOSAiC.csv",index_col=0)

# %%
ds_mosaic_full = xr.open_dataset(f"{base_dir}/mosaic-examples/MOSAiC_obs_combined_1h_v2.nc")
df_mosaic = pd.DataFrame({
    "Date": pd.to_datetime(ds_mosaic_full.time.to_series()),
    "lat": ds_mosaic_full.lat.to_series(),
    "lon": ds_mosaic_full.lon.to_series(),
    "obs_t2m": ds_mosaic_full.temp_2m.to_series(),
    "obs_10si": ds_mosaic_full.wspd_vec_mean_10m.to_series()
})

df_mosaic = df_mosaic.dropna().reset_index(drop=True)

# %%
df_2t_ctrl = t2m_ifs_ctrl.copy()
df_2t_ctrl= df_2t_ctrl.rename(columns={df_2t_ctrl.columns[0]: 'time'})
df_2t_ctrl['Date'] = pd.to_datetime(df_2t_ctrl['time'])

df_2t_hist = t2m_ifs_hist.copy()
df_2t_hist = df_2t_hist.rename(columns={df_2t_hist.columns[0]: 'time'})
df_2t_hist['Date'] = pd.to_datetime(df_2t_hist['time'])
 
df_merge = pd.merge(df_mosaic, df_2t_ctrl, on='Date', how='left')
df_merge = df_merge.sort_values('Date').reset_index(drop=True)
df_merge = df_merge.drop(["lat_y","lon_y"],axis=1)
df_merge = df_merge.rename(columns={"2t": "IFS_2t_ctrl"})

df_merge = pd.merge(df_merge, df_2t_hist, on='Date', how='left')
df_merge = df_merge.sort_values('Date').reset_index(drop=True)
df_merge = df_merge.drop(["lat","lon"],axis=1)
df_merge = df_merge.rename(columns={"2t": "IFS_2t_hist"})
display(df_merge)
# Out:
#                     Date     lat_x      lon_x    obs_t2m  obs_10si  \
# 0    2019-10-24 05:00:00  85.38783  129.25857 -11.397705  5.540913
# 1    2019-10-24 06:00:00  85.39099  129.22392 -11.465295  6.673965
# 2    2019-10-24 07:00:00  85.39376  129.18461 -11.751696  7.201428
# 3    2019-10-24 08:00:00  85.39659  129.14427 -12.204590  7.073128
# 4    2019-10-24 09:00:00  85.39908  129.09742 -12.584525  6.746246
# ...                  ...       ...        ...        ...       ...
# 5778 2020-09-18 00:00:00  89.04386  107.15948  -8.301785  4.690910
# 5779 2020-09-18 01:00:00  89.04825  107.06200  -8.807506  3.852696
# 5780 2020-09-18 02:00:00  89.05306  107.02649  -8.861598  3.823544
# 5781 2020-09-18 03:00:00  89.05784  107.05113  -8.822899  4.209018
# 5782 2020-09-18 04:00:00  89.06219  107.12212  -8.993374  3.684998
#
#                    time_x  IFS_2t_ctrl               time_y  IFS_2t_hist
# 0     2019-10-24 05:00:00   -27.224059  2019-10-24 05:00:00   -23.633513
# ...

# %%
df_merge2 = df_merge.copy()
df_10si_ctrl = wspd_ifs_ctrl.copy()
df_10si_ctrl = df_10si_ctrl.rename(columns={df_10si_ctrl.columns[0]: 'Date'})
df_10si_ctrl['Date'] = pd.to_datetime(df_10si_ctrl['Date'])

df_10si_hist = wspd_ifs_hist.copy()
df_10si_hist = df_10si_hist.rename(columns={df_10si_hist.columns[0]: 'Date'})
df_10si_hist['Date'] = pd.to_datetime(df_10si_hist['Date'])

df_merge2 = pd.merge(df_merge2, df_10si_hist, on='Date', how='left')
df_merge2 = df_merge2.sort_values('Date').reset_index(drop=True)
df_merge2 = df_merge2.drop(["lat","lon"],axis=1)
df_merge2 = df_merge2.rename(columns={"10si": "IFS_10si_hist"})

df_merge2 = pd.merge(df_merge2, df_10si_ctrl, on='Date', how='left')
df_merge2 = df_merge2.sort_values('Date').reset_index(drop=True)
df_merge2 = df_merge2.drop(["lat","lon"],axis=1)
df_merge2 = df_merge2.rename(columns={"10si": "IFS_10si_ctrl"})

display(df_merge2)
# Out:
#                     Date     lat_x      lon_x    obs_t2m  obs_10si  \
# 0    2019-10-24 05:00:00  85.38783  129.25857 -11.397705  5.540913
# 1    2019-10-24 06:00:00  85.39099  129.22392 -11.465295  6.673965
# 2    2019-10-24 07:00:00  85.39376  129.18461 -11.751696  7.201428
# 3    2019-10-24 08:00:00  85.39659  129.14427 -12.204590  7.073128
# 4    2019-10-24 09:00:00  85.39908  129.09742 -12.584525  6.746246
# ...                  ...       ...        ...        ...       ...
# 5778 2020-09-18 00:00:00  89.04386  107.15948  -8.301785  4.690910
# 5779 2020-09-18 01:00:00  89.04825  107.06200  -8.807506  3.852696
# 5780 2020-09-18 02:00:00  89.05306  107.02649  -8.861598  3.823544
# 5781 2020-09-18 03:00:00  89.05784  107.05113  -8.822899  4.209018
# 5782 2020-09-18 04:00:00  89.06219  107.12212  -8.993374  3.684998
#
#                    time_x  IFS_2t_ctrl               time_y  IFS_2t_hist  \
# 0     2019-10-24 05:00:00   -27.224059  2019-10-24 05:00:00   -23.633513
# ...

# %%
df_merge2_all = hourly_timestamp(df_merge2,'1h')

# %% [markdown]
# ### Standard Timeseries

# %%
fig, ax = plt.subplots(2,1,figsize=(12, 8))
ax[0].plot(df_merge2_all['Date'],df_merge2_all['obs_10si'],lw=1, color='indianred',label='MOSAiC (1hr)')
ax[0].plot(wspd_all_full['Datetime'],wspd_all_full['MOSAiC obs'], lw=1, color='steelblue',label='MOSAiC (3hr)')
ax[0].plot(wspd_all_full['Datetime'],wspd_all_full['CARRA2'], lw=1, color='darkorange',label='CARRA2 (3hr)')
ax[0].set_ylabel('10m wind speed (m s$^{-1}$)',fontsize=12)

ax[1].plot(t2m_all_full['Datetime'],t2m_all_full['MOSAiC obs'], lw=1, color='steelblue')
ax[1].plot(t2m_all_full['Datetime'],t2m_all_full['CARRA2'], lw=1, color='darkorange')
ax[1].set_ylabel('2m temperature ($^{o}$C)',fontsize=12)

for i in range(0,2):
    ax[i].grid(linewidth = 0.3)

ax[1].set_xlabel('Date')
ax[0].legend(fontsize=12)
plt.tight_layout()
plt.show()

#fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Timeseries.png',dpi=300,bbox_inches="tight")

# %% [markdown]
# ### Difference Timeseries

# %%
wspd_all_full['Diff'] = wspd_all_full['MOSAiC obs'] - wspd_all_full['CARRA2']
t2m_all_full['Diff'] = t2m_all_full['MOSAiC obs'] - t2m_all_full['CARRA2']

# %%
fig, ax = plt.subplots(2,1,figsize=(12, 8))
ax[0].plot(wspd_all_full['Datetime'],wspd_all_full['Diff'], lw=1, color='indianred',label='MOSAiC - CARRA2')
ax[0].set_ylabel('10m wind speed difference (m s$^{-1}$)',fontsize=12)

ax[1].plot(t2m_all_full['Datetime'],t2m_all_full['Diff'], lw=1, color='indianred')
ax[1].set_ylabel('2m temperature difference ($^{o}$C)',fontsize=12)

for i in range(0,2):
    ax[i].grid(linewidth = 0.3)

ax[1].set_xlabel('Date')
ax[0].legend(fontsize=12)
plt.tight_layout()
plt.show()

fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Difference_Timeseries.png',dpi=300,bbox_inches="tight")

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

hb = ax[0].hexbin(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2'],
    gridsize=50,cmap='plasma',mincnt=1)

ax[1].hexbin(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2'],
    gridsize=50,cmap='plasma',mincnt=1)

ax[0].axline((0, 0), (20,20), linestyle='-', color='grey', alpha=0.6,linewidth=1)
ax[0].set_xlim([0,20])
ax[0].set_ylim([0,20])
ax[0].set_title('10m wind speed (m s$^{-1}$)',fontsize=12)

ax[1].axline((-45, -45), (10,10), linestyle='-', color='grey', alpha=0.6,linewidth=1)
ax[1].set_xlim([-45,5])
ax[1].set_ylim([-45,5])
ax[1].set_title('2m temperature ($^{o}$C)',fontsize=12)

for i in range(0,2):
    ax[i].set_xlabel('MOSAiC')
    ax[i].set_ylabel('CARRA2')
    ax[i].grid(linewidth = 0.2)

# Stats
ax[0].text(15.5,5,f"\nr: \nRMSD: \nA.Diff: \n",
           fontsize=12,verticalalignment='top',horizontalalignment='right')
ax[0].text(15.5,5,f"\n{corr(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f} \n"
           f"{rmsd(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f}%\n"
           f"{absdiff(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f}%",
           fontsize=12,verticalalignment='top',horizontalalignment='left')


ax[1].text(-10,-32,f"\nr: \nRMSD: \nA.Diff: \n",
           fontsize=12,verticalalignment='top',horizontalalignment='right')
ax[1].text(-10,-32,f"\n{corr(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f} \n"
           f"{rmsd(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f}%\n"
           f"{absdiff(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f}%",
           fontsize=12,verticalalignment='top',horizontalalignment='left')

plt.tight_layout()
plt.show()

fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Scatter.png',dpi=300,bbox_inches="tight")

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].scatter(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2'],color='steelblue',
               s=80, edgecolors='white', linewidths=0.5)
ax[1].scatter(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2'],color='steelblue',
               s=80, edgecolors='white', linewidths=0.5)

ax[0].axline((0, 0), (20,20), linestyle='-', color='grey', alpha=0.6,linewidth=1)
ax[0].set_xlim([0,20])
ax[0].set_ylim([0,20])
ax[0].set_title('10m wind speed (m s$^{-1}$)',fontsize=12)

ax[1].axline((-45, -45), (10,10), linestyle='-', color='grey', alpha=0.6,linewidth=1)
ax[1].set_xlim([-45,5])
ax[1].set_ylim([-45,5])
ax[1].set_title('2m temperature ($^{o}$C)',fontsize=12)

for i in range(0,2):
    ax[i].set_xlabel('MOSAiC')
    ax[i].set_ylabel('CARRA2')
    ax[i].grid(linewidth = 0.2)

# Stats
ax[0].text(15.5,5,f"\nr: \nRMSD: \nA.Diff: \n",
           fontsize=12,verticalalignment='top',horizontalalignment='right')
ax[0].text(15.5,5,f"\n{corr(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f} \n"
           f"{rmsd(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f}%\n"
           f"{absdiff(wspd_all_full['MOSAiC obs'],wspd_all_full['CARRA2']):.2f}%",
           fontsize=12,verticalalignment='top',horizontalalignment='left')


ax[1].text(-10,-32,f"\nr: \nRMSD: \nA.Diff: \n",
           fontsize=12,verticalalignment='top',horizontalalignment='right')
ax[1].text(-10,-32,f"\n{corr(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f} \n"
           f"{rmsd(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f}%\n"
           f"{absdiff(t2m_all_full['MOSAiC obs'],t2m_all_full['CARRA2']):.2f}%",
           fontsize=12,verticalalignment='top',horizontalalignment='left')

plt.tight_layout()
plt.show()

fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Scatter.png',dpi=300,bbox_inches="tight")

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].hist(wspd_all_full['MOSAiC obs'], histtype='step', density=True,
                 bins=25, edgecolor='steelblue', linewidth=2, label='MOSAiC')
ax[0].hist(wspd_all_full['CARRA2'], histtype='step', density=True,
                 bins=25, edgecolor='darkorange', linewidth=2, label='CARRA2')

ax[1].hist(t2m_all_full['MOSAiC obs'], histtype='step', density=True,
                 bins=25, edgecolor='steelblue', linewidth=2, label='MOSAiC')
ax[1].hist(t2m_all_full['CARRA2'], histtype='step', density=True,
                 bins=25, edgecolor='darkorange', linewidth=2, label='CARRA2')

ax[0].set_xlabel('10m wind speed (m s$^{-1}$)')
ax[1].set_xlabel('2m temperature ($^{o}$C)')
ax[0].set_ylabel('Normalised Count')

for i in range(0,2):
    ax[i].grid(linewidth = 0.2)
    ax[i].legend()
    ax[i].set_ylim([0,0.18])

plt.tight_layout()
plt.show()

fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Hist.png',dpi=300,bbox_inches="tight")

# %%
fig, ax = plt.subplots(1,2,figsize=(10,5))

ax[0].hist(wspd_all_full['Diff'], histtype='step', density=True,
                 bins=25, edgecolor='steelblue', linewidth=2, label='MOSAiC - CARRA2')

ax[1].hist(t2m_all_full['Diff'], histtype='step', density=True,
                 bins=25, edgecolor='steelblue', linewidth=2, label='MOSAiC - CARRA2')

ax[0].set_xlabel('10m wind speed (m s$^{-1}$)')
ax[1].set_xlabel('2m temperature ($^{o}$C)')
ax[0].set_ylabel('Normalised Count')

for i in range(0,2):
    ax[i].grid(linewidth = 0.2)
    ax[i].legend()
    ax[i].set_ylim([0,0.37])

plt.tight_layout()
plt.show()

fig.savefig('C:/Users/Administrator/Documents/SnowPI_Hackathon/Figures/MOSAiC_CARRA2_Difference_Hist.png',dpi=300,bbox_inches="tight")

# %% [markdown]
# # Wind Speed Roughness
